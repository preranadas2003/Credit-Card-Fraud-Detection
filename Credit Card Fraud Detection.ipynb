# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
pd.set_option('display.max_columns', None) #to see all the columns

# %%
pd.set_option('display.max_rows', None)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# 284802 -0.689256  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920
# 284803  1.214756 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556
# 284804 -0.183699 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252
# 284805 -1.042082  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849
# 284806 -0.188093 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117
#
#              V20       V21       V22       V23       V24       V25       V26  \
# 284802  1.475829  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034
# 284803  0.059616  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255
# 284804  0.001396  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371
# 284805  0.127434  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668
# 284806  0.382948  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267
#
#              V27       V28  Amount  Class
# 284802  0.943651  0.823731    0.77      0
# 284803  0.068472 -0.053527   24.79      0
# 284804  0.004455 -0.026561   67.88      0
# 284805  0.108821  0.104533   10.00      0
# 284806 -0.002415  0.013649  217.00      0

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
for i in data.columns:
 print(i,':','\n',data[i].unique(),'\n')
# Out:
# Time :
#  [0.00000e+00 1.00000e+00 2.00000e+00 ... 1.72787e+05 1.72788e+05
#  1.72792e+05]
#
# V1 :
#  [-1.35980713  1.19185711 -1.35835406 ...  1.91956501 -0.24044005
#  -0.53341252]
#
# V2 :
#  [-0.07278117  0.26615071 -1.34016307 ... -0.30125385  0.53048251
#  -0.18973334]
#
# V3 :
#  [ 2.53634674  0.16648011  1.77320934 ... -3.24963981  0.70251023
#   0.70333737]
#
# V4 :
#  [ 1.37815522  0.44815408  0.37977959 ... -0.55782812  0.68979917
#  -0.50627124]
#
# V5 :
#  [-0.33832077  0.06001765 -0.50319813 ...  2.63051512 -0.37796113
#  -0.01254568]
#
# V6 :
#  [ 0.46238778 -0.08236081  1.80049938 ...  3.0312601   0.62370772
#  -0.64961669]
#
# V7 :
#  [ 0.23959855 -0.07880298  0.79146096 ... -0.29682653 -0.68617999
#   1.57700625]
#
# V8 :
#  [ 0.0986979   0.08510165  0.24767579 ...  0.70841718  0.67914546
#  -0.41465041]
#
# V9 :
#  [ 0.36378697 -0.25542513 -1.51465432 ...  0.43245405  0.39208671
#   0.48617951]
#
# V10 :
#  [ 0.09079417 -0.16697441  0.20764287 ... -0.48478176 -0.39912565
#  -0.91542665]
#
# V11 :
#  [-0.55159953  1.61272666  0.62450146 ...  0.41161374 -1.93384882
#  -1.04045834]
#
# V12 :
#  [-0.61780086  1.06523531  0.06608369 ...  0.06311886 -0.96288614
#  -0.03151305]
#
# V13 :
#  [-0.99138985  0.48909502  0.71729273 ... -0.18369869 -1.04208166
#  -0.1880929 ]
#
# V14 :
#  [-0.31116935 -0.1437723  -0.16594592 ... -0.51060184  0.44962444
#  -0.08431647]
#
# V15 :
#  [1.46817697 0.63555809 2.34586495 ... 1.32928351 1.96256312 0.04133346]
#
# V16 :
#  [-0.47040053  0.46391704 -2.89008319 ...  0.14071598 -0.60857713
#  -0.30262009]
#
# V17 :
#  [ 0.20797124 -0.11480466  1.10996938 ...  0.31350179  0.50992846
#  -0.66037665]
#
# V18 :
#  [ 0.02579058 -0.18336127 -0.12135931 ...  0.39565248  1.11398059
#   0.16742993]
#
# V19 :
#  [ 0.40399296 -0.14578304 -2.2618571  ... -0.57725184  2.89784877
#  -0.25611687]
#
# V20 :
#  [ 0.2514121  -0.06908314  0.52497973 ...  0.00139597  0.12743352
#   0.3829481 ]
#
# V21 :
#  [-0.01830678 -0.22577525  0.24799815 ...  0.23204504  0.26524492
#   0.26105733]
#
# V22 :
#  [ 0.27783758 -0.63867195  0.7716794  ...  0.57822901  0.80004874
#   0.64307844]
#
# V23 :
#  [-0.11047391  0.10128802  0.90941226 ... -0.03750086 -0.16329794
#   0.37677701]
#
# V24 :
#  [ 0.06692807 -0.33984648 -0.68928096 ...  0.64013388  0.12320524
#   0.00879738]
#
# V25 :
#  [ 0.12853936  0.1671704  -0.32764183 ...  0.26574545 -0.56915886
#  -0.4736487 ]
#
# V26 :
#  [-0.18911484  0.12589453 -0.13909657 ... -0.0873706   0.54666846
#  -0.81826712]
#
# V27 :
#  [ 0.13355838 -0.0089831  -0.05535279 ...  0.00445477  0.10882073
#  -0.00241531]
#
# V28 :
#  [-0.02105305  0.01472417 -0.05975184 ... -0.02656083  0.10453282
#   0.01364891]
#
# Amount :
#  [149.62   2.69 378.66 ... 381.05 337.54  95.63]
#
# Class :
#  [0 1]

# %%
data.describe(include='all')
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#                 V10           V11           V12           V13           V14  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.239053e-15  1.673327e-15 -1.247012e-15  8.190001e-16  1.207294e-15
# std    1.088850e+00  1.020713e+00  9.992014e-01  9.952742e-01  9.585956e-01
# min   -2.458826e+01 -4.797473e+00 -1.868371e+01 -5.791881e+00 -1.921433e+01
# 25%   -5.354257e-01 -7.624942e-01 -4.055715e-01 -6.485393e-01 -4.255740e-01
# 50%   -9.291738e-02 -3.275735e-02  1.400326e-01 -1.356806e-02  5.060132e-02
# 75%    4.539234e-01  7.395934e-01  6.182380e-01  6.625050e-01  4.931498e-01
# max    2.374514e+01  1.201891e+01  7.848392e+00  7.126883e+00  1.052677e+01
#
#                 V15           V16           V17           V18           V19  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   4.887456e-15  1.437716e-15 -3.772171e-16  9.564149e-16  1.039917e-15
# std    9.153160e-01  8.762529e-01  8.493371e-01  8.381762e-01  8.140405e-01
# min   -4.498945e+00 -1.412985e+01 -2.516280e+01 -9.498746e+00 -7.213527e+00
# 25%   -5.828843e-01 -4.680368e-01 -4.837483e-01 -4.988498e-01 -4.562989e-01
# 50%    4.807155e-02  6.641332e-02 -6.567575e-02 -3.636312e-03  3.734823e-03
# 75%    6.488208e-01  5.232963e-01  3.996750e-01  5.008067e-01  4.589494e-01
# max    8.877742e+00  1.731511e+01  9.253526e+00  5.041069e+00  5.591971e+00
#
#                 V20           V21           V22           V23           V24  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   6.406204e-16  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    7.709250e-01  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min   -5.449772e+01 -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%   -2.117214e-01 -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%   -6.248109e-02 -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    1.330408e-01  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    3.942090e+01  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), cmap='coolwarm', annot=False, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
data = data.dropna(subset=['Class'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#      Amount  Class
# 0  0.244964      0
# 1 -0.342475      0
# 2  1.160686      0
# 3  0.140534      0
# 4 -0.073403      0

# %%
data = data.drop(['Time'],axis=1)

# %%
data.shape
# Out:
# (284807, 30)

# %%
data.duplicated().any()
# Out:
# np.True_

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x='Class',data=data)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
x = data.drop(['Class'],axis=1)
y = data['Class']

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9992563437505668

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
precision_score(y_test,y_pred)
# Out:
# 0.890625

# %%
recall_score(y_test,y_pred)
# Out:
# 0.6263736263736264

# %%
f1_score(y_test,y_pred)
# Out:
# 0.7354838709677419

# %% [markdown]
# Undersampling

# %%
 normal = data[data['Class']==0]
 fraud = data[data['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.062708  1.428594  0.415427  3.450542  1.146990  0.678976  0.802250
# 1 -0.616285  1.223894  1.768980  0.998499 -0.022072  0.492910  0.267602
# 2  1.978608 -0.266232 -0.385184  0.146137 -0.449634 -0.323354 -0.513850
# 3  1.849842 -0.222619 -0.179344  1.097584 -0.382692  0.051221 -0.533197
# 4  1.411876 -1.440359  0.671583 -1.527771 -1.474256  0.570105 -1.576413
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.043968 -1.374090  1.276523 -1.650144 -0.219281  0.551271 -0.206944
# 1  0.034036  1.552574 -0.359330 -0.496899 -2.024312  3.028399  0.704649
# 2  0.030157  1.002430 -0.072317  0.788383  1.385399  0.617926  0.139304
# 3  0.099166  0.485093  0.346367  0.818945  1.300556  0.966225  0.084081
# 4  0.159790 -1.441371  1.443498 -0.014150 -0.079512  1.366742 -0.869900
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0 -1.424916 -0.058954 -0.313366 -0.322968 -0.434346 -0.129749  0.290594
# 1 -0.608668 -0.337586  0.409740  0.630196  0.630750  0.326535 -0.075182
# 2  0.326102  0.484228 -1.055576  0.542172  0.259304 -0.189470 -0.081525
# 3  0.418200  0.918496 -1.280967  0.635911 -0.432172 -0.097562  0.069307
# 4 -0.480894  0.188534 -0.145317  1.116218  0.406653 -0.136950 -0.041175
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.961360  0.037722  0.627370 -1.144285 -0.001384  0.020716  0.301490
# 1  0.545360 -0.339373 -0.453213  0.145262 -0.154952  0.538856  0.252516
# 2 -0.100836  0.295108 -0.379950 -0.335644 -0.925633  0.058862 -0.039131
# 3  0.192608  0.239900 -0.437605 -0.382723 -0.851275  0.058901 -0.026852
# 4  0.319835 -0.230592 -0.807194  0.477476  0.002701  0.065860  0.018485
#
#      Amount  Class
# 0 -0.323004      0
# 1 -0.231728      0
# 2 -0.349231      0
# 3 -0.177514      0
# 4 -0.112944      0

# %%
x = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9263157894736842

# %%
precision_score(y_test,y_pred)
# Out:
# 0.94

# %%
recall_score(y_test,y_pred)
# Out:
# 0.9215686274509803

# %%
f1_score(y_test,y_pred)
# Out:
# 0.9306930693069307

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8842105263157894

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.8773584905660378

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.8942307692307693

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred2)
sns.heatmap(cm, annot=True, fmt='d', cmap='seismic', xticklabels=["Not Fraud", "Fraud"], yticklabels=["Not Fraud", "Fraud"])
plt.title("Confusion Matrix - Decision Tree")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9473684210526315

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9893617021276596

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9489795918367347

# %%
 final_data = pd.DataFrame({'Models':['Logistic Regression','Decision Tree','Random Forest'],
                               "ACC":[accuracy_score(y_test,y_pred)*100,
                                      accuracy_score(y_test,y_pred2)*100,
                                      accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#                 Models        ACC
# 0  Logistic Regression  92.631579
# 1        Decision Tree  88.421053
# 2        Random Forest  94.736842

# %%
sns.barplot(x='Models', y='ACC', data=final_data, palette=['skyblue', 'lightgreen', 'salmon'])
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy (%)")
plt.show()
# Out:
# <ipython-input-119-0a71f7e17b06>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Models', y='ACC', data=final_data, palette=['skyblue', 'lightgreen', 'salmon'])

# %% [markdown]
# Oversampling

# %%
x = data.drop('Class',axis=1)
y = data['Class']

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
x_res,y_res = SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_res,y_res,test_size=0.2,random_state=42)

# %% [markdown]
# LR after Oversampling

# %%
log = LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9450652276608889

# %%
precision_score(y_test,y_pred)
# Out:
# 0.9728220977400038

# %%
recall_score(y_test,y_pred)
# Out:
# 0.9156409650382706

# %%
 f1_score(y_test,y_pred)
# Out:
# 0.9433658321860395

# %% [markdown]
# DT after Oversampling

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
 y_pred2 = dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9981649042479741

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9974582887020933

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9988727887569769

# %% [markdown]
# RF after Oversampling

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.999918238308078

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9998363993310551

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999181929736854

# %%
final_data = pd.DataFrame({'Models':['Logistic Regression','Decision Tree','Random Forest'],
                               "ACC":[accuracy_score(y_test,y_pred)*100,
                                      accuracy_score(y_test,y_pred2)*100,
                                      accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#                 Models        ACC
# 0  Logistic Regression  94.506523
# 1        Decision Tree  99.816490
# 2        Random Forest  99.991824

# %%
sns.barplot(x='Models', y='ACC', data=final_data, palette=['red', 'green', 'blue'])
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy (%)")
plt.show()
# Out:
# <ipython-input-116-3b00eb1d526c>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Models', y='ACC', data=final_data, palette=['red', 'green', 'blue'])

# %%
rf1 = RandomForestClassifier()
rf1.fit(x_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1,'creditcard.pkl')
# Out:
# ['creditcard.pkl']

# %%
model = joblib.load('creditcard.pkl')

# %%
joblib.dump(sc, 'scaler.pkl')
# Out:
# ['scaler.pkl']
